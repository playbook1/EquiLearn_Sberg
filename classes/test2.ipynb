# %%
! pip3 install agilerl
# Out:
# ...
#   Using cached agilerl-1.0.11-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached SuperSuit-3.9.3-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached accelerate-0.18.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached fastrand-1.8.0.tar.gz (7.9 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached flatten_dict-0.4.2-py2.py3-none-any.whl.metadata (9.2 kB)
# ...
#   Using cached h5py-3.12.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (2.5 kB)
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached minari-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached pettingzoo-1.24.3-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached pre_commit-3.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached redis-4.6.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (60 kB)
# ...
